# %% [markdown]
# # Title/Task
#
# ---

# %% [markdown]
# ### List of tasks
#
#   1. [Preproccessing](#1.-Preprocessing)
#     * Drop rows where None or Null exist
#     * Label preprocessing (genre)
#     * Poster Preprocessing

# %% [markdown]
# *__imports__*

# %%
# imports ...
import numpy as np
import pandas as pd

import math
import requests
from skimage import io
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %% [markdown]
# __helper functions__

# %%
file_type = ".jpg"


# gets the image from a url
def get_image_from_url(img_url):
        request = requests.head(img_url)
        if request.status_code == 200:
            return io.imread(img_url)
        else:
            return [] # make sure to handle this case if you use this method


# reads a directory of images, flattens the features to a single row then returns as a dataframe
def extract_features(features):
    new_df = []
    for feature in features:
        request = requests.head(feature)
        if request.status_code == 200:
            img = io.imread(feature)
            image_flat = img.flatten()
            new_df.append(image_flat)
    return new_df

# # helper for displaying an image
# def print_img(img, color=True):
#     plt.figure(figsize=(10, 6) )
#     if (color):
#         #plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) ) # need to change this colorspace to not use opencv - tbd
#     else:
#         plt.imshow(img, cmap="gray") # grayscale
#     plt.show()


# more coming

# %% [markdown]
# *__dataset directory paths__*

# %%
dataset_path = "../dataset/MovieGenre.csv"

posters_images_path = "../dataset/SampleMoviePosters/"

# %% [markdown]
# *__import datasets__*

# %%
dataset_orig_df = pd.read_csv(dataset_path)

dataset_orig_df[::3000]
# Out:
#         imdbId                            Imdb Link  \
# 0       114709   http://www.imdb.com/title/tt114709
# 3000     24852    http://www.imdb.com/title/tt24852
# 6000     84302    http://www.imdb.com/title/tt84302
# 9000    100280   http://www.imdb.com/title/tt100280
# 12000    42286    http://www.imdb.com/title/tt42286
# 15000  1391579  http://www.imdb.com/title/tt1391579
# 18000    49800    http://www.imdb.com/title/tt49800
# 21000  2111478  http://www.imdb.com/title/tt2111478
# 24000   477449   http://www.imdb.com/title/tt477449
# 27000    57262    http://www.imdb.com/title/tt57262
# 30000    80439    http://www.imdb.com/title/tt80439
# 33000  3257072  http://www.imdb.com/title/tt3257072
# 36000   325725   http://www.imdb.com/title/tt325725
# 39000  2473486  http://www.imdb.com/title/tt2473486
#
#                                                    Title  IMDB Score  \
# 0                                       Toy Story (1995)         8.3
# 3000                             Babes in Toyland (1934)         7.4
# 6000                  Maratonci trce pocasni krug (1982)         9.0
# 9000                              Nuns on the Run (1990)         5.9
# 12000                                Broken Arrow (1950)         7.2
# 15000                            The Dark Lurking (2009)         3.4
# 18000                                Storm Center (1956)         7.1
# 21000  Mea Maxima Culpa: Silence in the House of God ...         8.1
# 24000                      MC5: Kick Out the Jams (1999)         7.5
# 27000                              Love Is a Ball (1963)         6.0
# 30000                         Il bisbetico domato (1980)         7.7
# 33000                              Mahi va gorbeh (2013)         7.6
# 36000                    Legend of the Candy Cane (2001)         6.2
# 39000                                      Oxyana (2013)         7.2
#
#                             Genre  \
# 0      Animation|Adventure|Comedy
# 3000        Comedy|Family|Fantasy
# 6000                 Comedy|Drama
# 9000                 Comedy|Crime
# 12000       Drama|Romance|Western
# 15000        Action|Horror|Sci-Fi
# 18000                       Drama
# 21000                 Documentary
# 24000     Documentary|Short|Music
# 27000              Comedy|Romance
# 30000                      Comedy
# 33000      Drama|Mystery|Thriller
# 36000      Animation|Comedy|Drama
# 39000            Documentary|News
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 3000   https://images-na.ssl-images-amazon.com/images...
# 6000   https://images-na.ssl-images-amazon.com/images...
# 9000   https://images-na.ssl-images-amazon.com/images...
# 12000  https://images-na.ssl-images-amazon.com/images...
# 15000  https://images-na.ssl-images-amazon.com/images...
# 18000  https://images-na.ssl-images-amazon.com/images...
# 21000  https://images-na.ssl-images-amazon.com/images...
# 24000  https://images-na.ssl-images-amazon.com/images...
# 27000  https://images-na.ssl-images-amazon.com/images...
# 30000  https://images-na.ssl-images-amazon.com/images...
# 33000  https://images-na.ssl-images-amazon.com/images...
# 36000  https://images-na.ssl-images-amazon.com/images...
# 39000  https://images-na.ssl-images-amazon.com/images...

# %%
dataset_orig_df.shape
# Out:
# (40108, 6)

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# ---
#
# ### A.  *__drop rows where None or Null exist__*

# %%
dataset_edit_df = dataset_orig_df.dropna()

dataset_edit_df.shape
# Out:
# (39246, 6)

# %%
orig_df_size = dataset_orig_df.shape[0] # orig
mod_df_size = dataset_edit_df.shape[0] # after dropping rows

print("Number of rows dropped (contains Null/None):", orig_df_size - mod_df_size)
# Out:
# Number of rows dropped (contains Null/None): 862

# %%
dataset_edit_df[::3000]
# Out:
#         imdbId                            Imdb Link  \
# 0       114709   http://www.imdb.com/title/tt114709
# 3028    120363   http://www.imdb.com/title/tt120363
# 6033     83107    http://www.imdb.com/title/tt83107
# 9036    102982   http://www.imdb.com/title/tt102982
# 12039    24353    http://www.imdb.com/title/tt24353
# 15049   112491   http://www.imdb.com/title/tt112491
# 18103   446930   http://www.imdb.com/title/tt446930
# 21218   336693   http://www.imdb.com/title/tt336693
# 24304    92609    http://www.imdb.com/title/tt92609
# 27384   247394   http://www.imdb.com/title/tt247394
# 30479   248428   http://www.imdb.com/title/tt248428
# 33550   107415   http://www.imdb.com/title/tt107415
# 36680    57894    http://www.imdb.com/title/tt57894
# 39856  1287875  http://www.imdb.com/title/tt1287875
#
#                                                 Title  IMDB Score  \
# 0                                    Toy Story (1995)         8.3
# 3028                               Toy Story 2 (1999)         7.9
# 6033                         Some Kind of Hero (1982)         5.6
# 9036         Stinsen brinner... filmen alltsí« (1991)         6.8
# 12039                            Morning Glory (1933)         6.6
# 15049  Between the Devil and the Deep Blue Sea (1995)         7.2
# 18103                            Bekleme Odasi (2003)         6.5
# 21218                       The House Is Black (1963)         8.0
# 24304                                 Backfire (1988)         5.5
# 27384                                  Gumnaam (1965)         7.2
# 30479                                    Shiva (1989)         8.1
# 33550                                  Lifepod (1993)         5.9
# 36680                        BlÌÁznova kronika (1964)         7.2
# 39856                             Yeo-haeng-ja (2009)         7.6
#
#                             Genre  \
# 0      Animation|Adventure|Comedy
# 3028   Animation|Adventure|Comedy
# 6033           Comedy|Crime|Drama
# 9036               Comedy|Musical
# 12039               Drama|Romance
# 15049                       Drama
# 18103                       Drama
# 21218           Documentary|Short
# 24304      Drama|Mystery|Thriller
# 27384      Drama|Mystery|Thriller
# 30479                      Action
# 33550     Mystery|Sci-Fi|Thriller
# 36680    Adventure|Comedy|Fantasy
# 39856                       Drama
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 3028   https://images-na.ssl-images-amazon.com/images...
# 6033   https://images-na.ssl-images-amazon.com/images...
# 9036   https://images-na.ssl-images-amazon.com/images...
# 12039  https://images-na.ssl-images-amazon.com/images...
# 15049  https://images-na.ssl-images-amazon.com/images...
# 18103  https://images-na.ssl-images-amazon.com/images...
# 21218  https://images-na.ssl-images-amazon.com/images...
# 24304  https://images-na.ssl-images-amazon.com/images...
# 27384  https://images-na.ssl-images-amazon.com/images...
# 30479  https://images-na.ssl-images-amazon.com/images...
# 33550  https://images-na.ssl-images-amazon.com/images...
# 36680  https://images-na.ssl-images-amazon.com/images...
# 39856  https://images-na.ssl-images-amazon.com/images...

# %% [markdown]
# ---
#
# ### B. __*Label preprocessing (genre)*__

# %% [markdown]
# __*get label column*__

# %%
label = dataset_edit_df["Genre"]
label[::3000]
# Out:
# 0        Animation|Adventure|Comedy
# 3028     Animation|Adventure|Comedy
# 6033             Comedy|Crime|Drama
# 9036                 Comedy|Musical
# 12039                 Drama|Romance
# 15049                         Drama
# 18103                         Drama
# 21218             Documentary|Short
# 24304        Drama|Mystery|Thriller
# 27384        Drama|Mystery|Thriller
# 30479                        Action
# 33550       Mystery|Sci-Fi|Thriller
# 36680      Adventure|Comedy|Fantasy
# 39856                         Drama
# Name: Genre, dtype: object

# %%
label.shape
# Out:
# (39246,)

# %% [markdown]
# __*split the label to only show one genre*__

# %%
#returns the first/main genre string - don't care about sub-genres...
def get_one_genre(row):
    return row.split("|")[0] # yolo

label_edit = label.apply(get_one_genre)

# %%
label_edit[::3000]
# Out:
# 0          Animation
# 3028       Animation
# 6033          Comedy
# 9036          Comedy
# 12039          Drama
# 15049          Drama
# 18103          Drama
# 21218    Documentary
# 24304          Drama
# 27384          Drama
# 30479         Action
# 33550        Mystery
# 36680      Adventure
# 39856          Drama
# Name: Genre, dtype: object

# %% [markdown]
# __*count of each genre*__

# %%
label_edit.value_counts()
# Out:
# Drama          9776
# Comedy         9655
# Action         4722
# Documentary    3521
# Crime          2546
# Horror         1970
# Adventure      1674
# Animation      1624
# Biography      1222
# Thriller        397
# Short           390
# Western         315
# Fantasy         272
# Mystery         256
# Family          243
# Romance         203
# Sci-Fi          192
# Musical         115
# War              65
# Music            36
# History          24
# Film-Noir        16
# Adult             7
# Talk-Show         3
# Sport             2
# Name: Genre, dtype: int64

# %% [markdown]
# __*one-hot-encode labels*__

# %%
#one hot encoding
label_ohe = pd.get_dummies(label_edit)

label_ohe.columns
# Out:
# Index(['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy',
#        'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir',
#        'History', 'Horror', 'Music', 'Musical', 'Mystery', 'Romance', 'Sci-Fi',
#        'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
label_ohe[::3000] # <---- this is out label for when we do training/testing
# Out:
#        Action  Adult  Adventure  Animation  Biography  Comedy  Crime  \
# 0           0      0          0          1          0       0      0
# 3028        0      0          0          1          0       0      0
# 6033        0      0          0          0          0       1      0
# 9036        0      0          0          0          0       1      0
# 12039       0      0          0          0          0       0      0
# 15049       0      0          0          0          0       0      0
# 18103       0      0          0          0          0       0      0
# 21218       0      0          0          0          0       0      0
# 24304       0      0          0          0          0       0      0
# 27384       0      0          0          0          0       0      0
# 30479       1      0          0          0          0       0      0
# 33550       0      0          0          0          0       0      0
# 36680       0      0          1          0          0       0      0
# 39856       0      0          0          0          0       0      0
#
#        Documentary  Drama  Family  ...  Musical  Mystery  Romance  Sci-Fi  \
# 0                0      0       0  ...        0        0        0       0
# 3028             0      0       0  ...        0        0        0       0
# 6033             0      0       0  ...        0        0        0       0
# 9036             0      0       0  ...        0        0        0       0
# 12039            0      1       0  ...        0        0        0       0
# 15049            0      1       0  ...        0        0        0       0
# 18103            0      1       0  ...        0        0        0       0
# 21218            1      0       0  ...        0        0        0       0
# 24304            0      1       0  ...        0        0        0       0
# 27384            0      1       0  ...        0        0        0       0
# 30479            0      0       0  ...        0        0        0       0
# 33550            0      0       0  ...        0        1        0       0
# 36680            0      0       0  ...        0        0        0       0
# 39856            0      1       0  ...        0        0        0       0
#
#        Short  Sport  Talk-Show  Thriller  War  Western
# 0          0      0          0         0    0        0
# 3028       0      0          0         0    0        0
# 6033       0      0          0         0    0        0
# 9036       0      0          0         0    0        0
# 12039      0      0          0         0    0        0
# 15049      0      0          0         0    0        0
# 18103      0      0          0         0    0        0
# 21218      0      0          0         0    0        0
# 24304      0      0          0         0    0        0
# 27384      0      0          0         0    0        0
# 30479      0      0          0         0    0        0
# 33550      0      0          0         0    0        0
# 36680      0      0          0         0    0        0
# 39856      0      0          0         0    0        0
#
# [14 rows x 25 columns]

# %% [markdown]
# ---
#
# ### C. __*Poster Preprocessing*__

# %% [markdown]
# *__ gather poster links __*

# %%
poster_links = dataset_edit_df['Poster']

poster_links.shape
# Out:
# (39246,)

# %%
sample_poster_url = poster_links[0]

print("Sample image url:\n", sample_poster_url)
# Out:
# Sample image url:
#  https://images-na.ssl-images-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_UX182_CR0,0,182,268_AL_.jpg

# %%
poster_folder = "../dataset/posters/"
file_extension = ".jpg"

file_name_ids = dataset_edit_df["imdbId"] # for naming the image file

for name, link in zip(file_name_ids, poster_links):
    file_name = str(name) + file_extension
    result = requests.get(link, stream=True)
    image = result.raw.read()
    open(poster_folder + file_name, "wb").write(image)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /usr/local/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /usr/local/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x12dda0f60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /usr/local/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='images-na.ssl-images-amazon.com', port=443): Max retries exceeded with url: /images/M/MV5BZDZiODcwY2ItODBhNi00NTA5LWJhMWMtYmU5M2RlMTZhMGI0XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_UX182_CR0,0,182,268_AL_.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12dda0f60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-50-f41035ab6024> in <module>
#       6 for name, link in zip(file_name_ids, poster_links):
#       7     file_name = str(name) + file_extension
# ----> 8     result = requests.get(link, stream=True)
#       9     image = result.raw.read()
#      10     open(poster_folder + file_name, "wb").write(image)
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='images-na.ssl-images-amazon.com', port=443): Max retries exceeded with url: /images/M/MV5BZDZiODcwY2ItODBhNi00NTA5LWJhMWMtYmU5M2RlMTZhMGI0XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_UX182_CR0,0,182,268_AL_.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12dda0f60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# __*save images to disk*__
